# %%
import pandas as pd

#READ THE CSV FILE
df = pd.read_csv('coffee.csv')

#PRINT OUT
print(df.columns)
# Out:
# Index(['transaction_id', 'transaction_date', 'transaction_time',
#        'transaction_qty', 'store_id', 'store_location', 'product_id',
#        'unit_price', 'product_category', 'product_type', 'product_detail'],
#       dtype='object')

# %%
total_orders = df.groupby(['product_category', 'product_type']).agg(total_order=('unit_price', 'sum')).reset_index()

#PRINT OUT
print(total_orders)

#PLOT DISPLAY
plt.figure(figsize=(15, 10))
plt.barh(total_orders['product_type'], total_orders['total_order'], color='green')
plt.xlabel('Total Orders')
plt.ylabel('Product')
plt.title('Total Orders For Each Product Type')
plt.show()
# Out:
#       product_category           product_type  total_order
# 0               Bakery               Biscotti     19528.78
# 1               Bakery                 Pastry     25477.49
# 2               Bakery                  Scone     35957.87
# 3              Branded               Clothing      6163.00
# 4              Branded             Housewares      7074.00
# 5               Coffee       Barista Espresso     59956.25
# 6               Coffee            Drip coffee     21065.00
# 7               Coffee  Gourmet brewed coffee     45605.60
# 8               Coffee  Organic brewed coffee     24601.30
# 9               Coffee  Premium brewed coffee     25401.15
# 10        Coffee beans         Espresso Beans      5560.25
# 11        Coffee beans          Gourmet Beans      6798.00
# 12        Coffee beans            Green beans      1340.00
# 13        Coffee beans      House blend Beans      3294.00
# 14        Coffee beans          Organic Beans      8419.50
# ...
